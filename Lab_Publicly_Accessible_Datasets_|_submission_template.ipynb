# %% [markdown]
# <a href="https://colab.research.google.com/github/kentlingcampbell/MSBX5500-002SecurityAnalyticsS21/blob/main/Lab_Publicly_Accessible_Datasets_%7C_submission_template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Template for deliverable for https://classes.daveeargle.com/security-analytics-assignments/labs/lab-publicly-accessible-datasets.html

# %%
import pandas as pd

# %%
def do_openml():
  # For this lab, do _not_ use sklearn's fetch_openml(). The generalization described
  # in the lab doc does _not work_ consistently.
  # But I'm leaving it as-is because the purpose of this is to teach you url hacking.
  df = pd.read_csv('https://www.openml.org/data/get_csv/22044419')
  return df
phish_url = do_openml()
phish_url.head()
# Out:
#    Querylength  domain_token_count  path_token_count  avgdomaintokenlen  \
# 0            0                   4                 4               6.25
# 1           22                   4                10               6.25
# 2           23                   4                10               6.25
# 3           22                   4                10               6.25
# 4           23                   4                10               6.25
#
#    longdomaintokenlen  avgpathtokenlen  tld  charcompvowels  charcompace  \
# 0                  17             3.75    4               4            2
# 1                  17             3.50    4              19           10
# 2                  17             3.50    4              19           10
# 3                  17             3.50    4              19           10
# 4                  17             3.50    4              19           10
#
#    ldl_url  ...  SymbolCount_FileName  SymbolCount_Extension  \
# ...

# %%
def do_github():
  df = pd.read_csv('https://raw.githubusercontent.com/kentlingcampbell/MSBX5500-002SecurityAnalyticsS21/main/All_cleaned.csv?raw=true')
  return df
spambase_44 = do_github()
spambase_44.head()
# Out:
#    Querylength  domain_token_count  path_token_count  avgdomaintokenlen  \
# 0            0                   4                 4               6.25
# 1           22                   4                10               6.25
# 2           23                   4                10               6.25
# 3           22                   4                10               6.25
# 4           23                   4                10               6.25
#
#    longdomaintokenlen  avgpathtokenlen  tld  charcompvowels  charcompace  \
# 0                  17             3.75    4               4            2
# 1                  17             3.50    4              19           10
# 2                  17             3.50    4              19           10
# 3                  17             3.50    4              19           10
# 4                  17             3.50    4              19           10
#
#    ldl_url  ...  SymbolCount_FileName  SymbolCount_Extension  \
# ...

# %%
def do_cloud_storage():
  # google drive, dropbox, etc. Not AWS or GCP or the like -- that's next. 
  df = pd.read_csv('https://drive.google.com/u/0/uc?id=1j-uqjintdr2KOZ8YGvhmlHxg_IQe5E2V&export=download')
  return df
spambase_44 = do_cloud_storage()
spambase_44.head()
# Out:
#    Querylength  domain_token_count  path_token_count  avgdomaintokenlen  \
# 0            0                   4                 4               6.25
# 1           22                   4                10               6.25
# 2           23                   4                10               6.25
# 3           22                   4                10               6.25
# 4           23                   4                10               6.25
#
#    longdomaintokenlen  avgpathtokenlen  tld  charcompvowels  charcompace  \
# 0                  17             3.75    4               4            2
# 1                  17             3.50    4              19           10
# 2                  17             3.50    4              19           10
# 3                  17             3.50    4              19           10
# 4                  17             3.50    4              19           10
#
#    ldl_url  ...  SymbolCount_FileName  SymbolCount_Extension  \
# ...

# %%
def do_cloud_computing_storage():
  # For this one, One of the cloud computing providers such as AWS or GCP. 
  # Not dropbox or google drive.
  df = pd.read_csv('https://s3.us-east-2.amazonaws.com/my.dog.spot.publicdata/All_cleaned.csv')
  return df
spambase_44 = do_cloud_computing_storage()
spambase_44.head()
# Out:
#    Querylength  domain_token_count  path_token_count  avgdomaintokenlen  \
# 0            0                   4                 4               6.25
# 1           22                   4                10               6.25
# 2           23                   4                10               6.25
# 3           22                   4                10               6.25
# 4           23                   4                10               6.25
#
#    longdomaintokenlen  avgpathtokenlen  tld  charcompvowels  charcompace  \
# 0                  17             3.75    4               4            2
# 1                  17             3.50    4              19           10
# 2                  17             3.50    4              19           10
# 3                  17             3.50    4              19           10
# 4                  17             3.50    4              19           10
#
#    ldl_url  ...  SymbolCount_FileName  SymbolCount_Extension  \
# ...
